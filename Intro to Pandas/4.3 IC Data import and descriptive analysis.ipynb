# %% [markdown]
# ## Importing Libraries

# %%
#import libraries

import pandas as pd
import numpy as np
import os

# %%
#import data
df = pd.read_csv(r"C:\Users\91928\Documents\Instacart Basket Analysis\Data\Original Data\orders.csv",index_col = False)

# %%
path=r'C:\Users\91928\Documents\Instacart Basket Analysis\Data\Original Data'

# %%
df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     nan
# 1                        7                15.00000
# 2                       12                21.00000
# ...

# %%
path
# Out:
# 'C:\\Users\\91928\\Documents\\Instacart Basket Analysis\\Data\\Original Data'

# %%
df=pd.read_csv(os.path.join(path,'orders.csv'),index_col = False)

# %%
print(df)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     nan
# 1                        7                15.00000
# 2                       12                21.00000
# ...

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
df.tail(10)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421073   2307371   206209    prior             5          4
# 3421074   3186442   206209    prior             6          0
# 3421075    550836   206209    prior             7          2
# 3421076   2129269   206209    prior             8          3
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421073                 15                     3.0
# 3421074                 16                     3.0
# 3421075                 13                     9.0
# 3421076                 17                    22.0
# ...

# %%
df.shape
# Out:
# (3421083, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %% [raw]
# df.dtypes

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count 3421083.00000 3421083.00000 3421083.00000 3421083.00000
# mean  1710542.00000  102978.20806      17.15486       2.77622
# std    987581.73982   59533.71779      17.73316       2.04683
# min         1.00000       1.00000       1.00000       0.00000
# 25%    855271.50000   51394.00000       5.00000       1.00000
# 50%   1710542.00000  102689.00000      11.00000       3.00000
# 75%   2565812.50000  154385.00000      23.00000       5.00000
# max   3421083.00000  206209.00000     100.00000       6.00000
#
#        order_hour_of_day  days_since_prior_order
# count      3421083.00000           3214874.00000
# mean            13.45202                11.11484
# std              4.22609                 9.20674
# min              0.00000                 0.00000
# 25%             10.00000                 4.00000
# 50%             13.00000                 7.00000
# 75%             16.00000                15.00000
# ...

# %%
df.describe().applymap('{:,.2f}'.format)
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3,421,083.00  3,421,083.00  3,421,083.00  3,421,083.00
# mean   1,710,542.00    102,978.21         17.15          2.78
# std      987,581.74     59,533.72         17.73          2.05
# min            1.00          1.00          1.00          0.00
# 25%      855,271.50     51,394.00          5.00          1.00
# 50%    1,710,542.00    102,689.00         11.00          3.00
# 75%    2,565,812.50    154,385.00         23.00          5.00
# max    3,421,083.00    206,209.00        100.00          6.00
#
#       order_hour_of_day days_since_prior_order
# count      3,421,083.00           3,214,874.00
# mean              13.45                  11.11
# std                4.23                   9.21
# min                0.00                   0.00
# 25%               10.00                   4.00
# 50%               13.00                   7.00
# 75%               16.00                  15.00
# ...

# %%
df = pd.read_csv(os.path.join(path,'orders.csv'),nrows = 1000)

# %%
df.tail(100)
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 900   1578027       58    prior             4          0                 17
# 901    164627       58    prior             5          0                  7
# 902   3097573       58    prior             6          4                 18
# 903   1089058       58    prior             7          0                  9
# 904    326173       58    prior             8          2                 10
# ..        ...      ...      ...           ...        ...                ...
# 995   2302602       64    prior             7          5                 20
# 996   3215917       64    prior             8          6                 17
# 997   2754807       64    prior             9          6                 15
# 998   3129760       64    prior            10          1                 10
# 999   2639013       64    train            11          0                 13
#
#      days_since_prior_order
# ...

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path,'orders.csv'),usecols = vars_list)

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
S
