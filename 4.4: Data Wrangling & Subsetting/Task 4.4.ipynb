# %% [markdown]
# ## Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path =r'C:\Users\91928\Documents\Instacart Basket Analysis\Data\Original Data'
path2 = r'C:\Users\91928\Documents\Instacart Basket Analysis\Data'

# %%
#impoting Data sets
df_ords = pd.read_csv(os.path.join(path, 'orders.csv'),index_col =False)
df_prods = pd.read_csv(os.path.join(path, 'products.csv'),index_col =False)
df_dept = pd.read_csv(os.path.join(path, 'departments.csv'),index_col =False)

# %%
df_ords.head(10)
# Out:
#   order_id user_id  order_number  order_day  order_hour_of_day  \
# 0  2539329       1             1          2                  8
# 1  2398795       1             2          3                  7
# 2   473747       1             3          3                 12
# 3  2254736       1             4          4                  7
# 4   431534       1             5          4                 15
# 5  3367565       1             6          2                  7
# 6   550135       1             7          1                  9
# 7  3108588       1             8          1                 14
# 8  2295261       1             9          1                 16
# 9  2550362       1            10          4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0
# 5                    19.0
# 6                    20.0
# 7                    14.0
# 8                     0.0
# ...

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %% [markdown]
# ## Data Wrangling

# %%
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# another identifier variable in the df_ords dataframe that doesn’t need to be included in the analysis
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
#renaming the column
df_ords.rename(columns = {'order_dow' : 'order_day'},inplace =True)

# %%
df_ords.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')

# %%
df_prods.head(10)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
# 5           6                                       Dry Nose Oil        11
# 6           7                     Pure Coconut Water With Orange        98
# 7           8                  Cut Russet Potatoes Steam N' Mash       116
# 8           9                  Light Strawberry Blueberry Yogurt       120
# 9          10     Sparkling Orange Juice & Prickly Pear Beverage       115
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# ...

# %%
#busiest hour is for placing orders
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
df_dept.head(10)
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dept.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dept_T = df_dept.T

# %%
df_dept_T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dept_T.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
new_header =df_dept_T.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dept_T_new = df_dept_T[1:]

# %%
df_dept_T_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dept_T_new.columns = new_header

# %%
data_dict = df_dept_T_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
##the meaning behind a value of 4 in the "department_id" column within the df_prods dataframe using a data dictionary.
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#the breakfast item sales can be obtained from department_id = 14
df_prods_breakfast = df_prods.loc[df_prods['department_id'] == 14 ]

# %%
#subset containing breakfast
df_prods_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
df_prods_snacks = df_prods.loc[df_prods['department_id'].isin([5,7,19,20])]

# %%
df_prods_snacks
# Out:
#        product_id                                    product_name  aisle_id  \
# 0               1                      Chocolate Sandwich Cookies        61
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# ...           ...                                             ...       ...
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49683       49679                         Famous Chocolate Wafers        61
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# total counts of new dataframe
df_prods_snacks.shape
# Out:
# (13007, 5)

# %%
##information regarding the user_id = 1
df_ords_usr = df_ords.loc[df_ords['user_id'] == '1']

# %%
df_ords_usr
# Out:
#    order_id user_id  order_number  order_day  order_hour_of_day  \
# 0   2539329       1             1          2                  8
# 1   2398795       1             2          3                  7
# 2    473747       1             3          3                 12
# 3   2254736       1             4          4                  7
# 4    431534       1             5          4                 15
# 5   3367565       1             6          2                  7
# 6    550135       1             7          1                  9
# 7   3108588       1             8          1                 14
# 8   2295261       1             9          1                 16
# 9   2550362       1            10          4                  8
# 10  1187899       1            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# ...

# %%
#details about user_id = 1
df_ords_usr.describe()
# Out:
#        order_number  order_day  order_hour_of_day  days_since_prior_order
# count     11.000000  11.000000          11.000000               10.000000
# mean       6.000000   2.636364          10.090909               19.000000
# std        3.316625   1.286291           3.477198                9.030811
# min        1.000000   1.000000           7.000000                0.000000
# 25%        3.500000   1.500000           7.500000               14.250000
# 50%        6.000000   3.000000           8.000000               19.500000
# 75%        8.500000   4.000000          13.000000               26.250000
# max       11.000000   4.000000          16.000000               30.000000

# %%
#Exporting your df_ords dataframe as “orders_wrangled.csv” in “Prepared Data” folder.
df_ords.to_csv(os.path.join(path2,'Prepared Data','orders_wrangled2.csv'))

# %%
#Exporting the df_dep_t_new dataframe as “departments_wrangled.csv” in “Prepared Data” foldr
df_dept_T_new.to_csv(os.path.join(path2,'Prepared Data','departments_wrangled.csv'))
